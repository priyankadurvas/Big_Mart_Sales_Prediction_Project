# %%
#!pip install pandas numpy seaborn matplotlib klib dtale scikit-learn joblib

# %%
import pandas as pd 
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dc1 = pd.read_csv(r'/Users/adityatripathi/Desktop/Big Mart Sales Files/train.csv')
dc2 = pd.read_csv(r'/Users/adityatripathi/Desktop/Big Mart Sales Files/test.csv')

# %%
dc1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dc2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
mean2 = dc2['Item_Weight'].mean()

# %%
dc2['Item_Weight']=dc2['Item_Weight'].fillna(mean2)

# %%
dc2.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
dc1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
mean1 = dc1['Item_Weight'].mean()

# %%
dc1['Item_Weight']=dc1['Item_Weight'].fillna(mean1)

# %%
dc1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dc2.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#mode1 = dc1['Outlet_Size'].mode()[0]

# %%
#dc1['Outlet_Size']=dc1['Outlet_Size'].fillna(mode1)

# %%
#dc1.isnull().sum()

# %%
#mode2 = dc2['Outlet_Size'].mode()[0]

# %%
#dc2['Outlet_Size']=dc2['Outlet_Size'].fillna(mode2)

# %%
#dc2.isnull().sum()

# %%
least_freq = dc1['Outlet_Size'].value_counts().idxmin()
dc1['Outlet_Size'].fillna(least_freq, inplace=True)

# %%
dc1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
dc1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dc1['Outlet_Size'].value_counts()
# Out:
# High      3342
# Medium    2793
# Small     2388
# Name: Outlet_Size, dtype: int64

# %%
least_freq1 = dc2['Outlet_Size'].value_counts().idxmin()
dc2['Outlet_Size'].fillna(least_freq1, inplace=True)

# %%
dc2.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
dc2['Outlet_Size'].value_counts()
# Out:
# High      2227
# Medium    1862
# Small     1592
# Name: Outlet_Size, dtype: int64

# %%
dc1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #EXPLORATORY DATA ANALYSIS

# %%
sns.set()

# %%
sns.set_style('whitegrid')

# %%
sns.distplot(dc1.Item_Weight)
# Out:
# /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='Item_Weight', ylabel='Density'>

# %%
sns.catplot(x = 'Outlet_Size' , data = dc1)

# %%
z = dc1.copy()

# %%
sns.pairplot(z)

# %%
sns.heatmap(dc1.corr())
# Out:
# <AxesSubplot: >

# %% [markdown]
# There does not seems to be any co-relation between any of the variables as the co-relation score does not seems to exceed 0.6. So, we can safely conclude that no variable is dependent on another variable.

# %%
dc1.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
from pandas_profiling import ProfileReport
# Out:
# /var/folders/x2/klypyxc135nfqxlbmhpj3zq40000gn/T/ipykernel_76968/2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
report = ProfileReport(dc1, title = 'report')

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-04-13 21:41:25.390888&quot;&gt;&lt;title&gt;report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
dc1.drop(['Item_Identifier','Outlet_Identifier'],axis =1,inplace=True)
dc2.drop(['Item_Identifier','Outlet_Identifier'],axis =1,inplace=True)

# %%
dc1
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 0        9.300000                 1         0.016047          4  249.809204
# 1        5.920000                 2         0.019278         14   48.269199
# 2       17.500000                 1         0.016760         10  141.617996
# 3       19.200001                 2         0.000000          6  182.095001
# 4        8.930000                 1         0.000000          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518     6.865000                 1         0.056783         13  214.521805
# 8519     8.380000                 2         0.046982          0  108.156998
# 8520    10.600000                 1         0.035186          8   85.122398
# 8521     7.210000                 2         0.145221         13  103.133202
# 8522    14.800000                 1         0.044878         14   75.467003
#
# ...

# %%
dc2
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0       20.750000          Low Fat         0.007565         Snack Foods
# 1        8.300000              reg         0.038428               Dairy
# 2       14.600000          Low Fat         0.099575              Others
# 3        7.315000          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.013496         Snack Foods
# 5677     7.600000          Regular         0.142991       Starchy Foods
# 5678    10.000000          Low Fat         0.073529  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.104720              Canned
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# ...

# %%
import klib

# %%
klib.data_cleaning(dc1)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.28 MB (-59.57%)
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 0        9.300000                 1         0.016047          4  249.809204
# 1        5.920000                 2         0.019278         14   48.269199
# 2       17.500000                 1         0.016760         10  141.617996
# 3       19.200001                 2         0.000000          6  182.095001
# 4        8.930000                 1         0.000000          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518     6.865000                 1         0.056783         13  214.521805
# 8519     8.380000                 2         0.046982          0  108.156998
# ...

# %%
dc1
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 0        9.300000                 1         0.016047          4  249.809204
# 1        5.920000                 2         0.019278         14   48.269199
# 2       17.500000                 1         0.016760         10  141.617996
# 3       19.200001                 2         0.000000          6  182.095001
# 4        8.930000                 1         0.000000          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518     6.865000                 1         0.056783         13  214.521805
# 8519     8.380000                 2         0.046982          0  108.156998
# 8520    10.600000                 1         0.035186          8   85.122398
# 8521     7.210000                 2         0.145221         13  103.133202
# 8522    14.800000                 1         0.044878         14   75.467003
#
# ...

# %%
dc1 = klib.convert_datatypes(dc1)

# %%
dc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float32
#  1   Item_Fat_Content           8523 non-null   int8
#  2   Item_Visibility            8523 non-null   float32
#  3   Item_Type                  8523 non-null   int8
#  4   Item_MRP                   8523 non-null   float32
#  5   Outlet_Establishment_Year  8523 non-null   int16
#  6   Outlet_Size                8523 non-null   int8
#  7   Outlet_Location_Type       8523 non-null   int8
#  8   Outlet_Type                8523 non-null   int8
#  9   Item_Outlet_Sales          8523 non-null   float32
# dtypes: float32(4), int16(1), int8(5)
# memory usage: 191.6 KB

# %% [markdown]
# LABELLING:

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dc1['Item_Fat_Content']= le.fit_transform(dc1['Item_Fat_Content'])
dc1['Item_Type']= le.fit_transform(dc1['Item_Type'])
dc1['Outlet_Size']= le.fit_transform(dc1['Outlet_Size'])
dc1['Outlet_Location_Type']= le.fit_transform(dc1['Outlet_Location_Type'])
dc1['Outlet_Type']= le.fit_transform(dc1['Outlet_Type'])

# %%
dc1
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 0        9.300000                 1         0.016047          4  249.809204
# 1        5.920000                 2         0.019278         14   48.269199
# 2       17.500000                 1         0.016760         10  141.617996
# 3       19.200001                 2         0.000000          6  182.095001
# 4        8.930000                 1         0.000000          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518     6.865000                 1         0.056783         13  214.521805
# 8519     8.380000                 2         0.046982          0  108.156998
# 8520    10.600000                 1         0.035186          8   85.122398
# 8521     7.210000                 2         0.145221         13  103.133202
# 8522    14.800000                 1         0.044878         14   75.467003
#
# ...

# %% [markdown]
# Train and Test:

# %%
x = dc1.drop('Item_Outlet_Sales', axis=1)

# %%
y = dc1['Item_Outlet_Sales']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y,random_state = 101, test_size = 0.25)

# %%
x_train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 5274    15.100000                 2         0.067021         13  260.330414
# 2697    16.250000                 0         0.145913          4   95.441002
# 1976    12.857645                 1         0.068754          9  127.967796
# 5139    12.857645                 1         0.110736          0   35.287399
# 8073    16.200001                 1         0.103634          3  101.399002
# ...           ...               ...              ...        ...         ...
# 599      5.000000                 1         0.044005         14  188.852997
# 5695    14.650000                 1         0.170664          7   56.461399
# 8006    12.500000                 1         0.018849          8   96.738403
# 1361     9.695000                 2         0.129009          0  226.940399
# 1547    15.700000                 1         0.161317          9   57.556198
#
# ...

# %%
x_test
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 8179    11.000000                 1         0.055163          8  100.335800
# 8355    18.000000                 1         0.038979         13  148.641800
# 3411     7.720000                 2         0.074731          1   77.598602
# 7089    20.700001                 1         0.049035          6   39.950600
# 6954     7.550000                 1         0.027225          3  152.934006
# ...           ...               ...              ...        ...         ...
# 4292    17.250000                 1         0.037155         14  166.452606
# 4130    19.350000                 2         0.066832         14  163.886795
# 5633    13.000000                 4         0.044976         14  176.205399
# 2541     6.765000                 2         0.087260          5  105.030602
# 6985    12.857645                 2         0.020312         10   98.104202
#
# ...

# %%
y_train
# Out:
# 5274    5424.938477
# 2697     193.082001
# 1976     254.335602
# 5139     988.047180
# 8073    1031.989990
#            ...
# 599     5502.836914
# 5695    1436.796387
# 8006    2167.844727
# 1361    2700.484863
# 1547     829.586792
# Name: Item_Outlet_Sales, Length: 6392, dtype: float32

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaled_train = scaler.fit_transform(x_train)
x_scaled_test= scaler.fit_transform(x_test)

# %%
x_scaled_train
# Out:
# array([[ 5.33031667e-01,  9.80950140e-01,  1.47021026e-02, ...,
#         -1.10499679e+00,  1.08970523e+00, -2.59888051e-01],
#        [ 8.06324174e-01, -2.11393303e+00,  1.54505133e+00, ...,
#         -1.10499679e+00,  1.08970523e+00, -1.50891393e+00],
#        [ 1.45476610e-04, -5.66491443e-01,  4.83103227e-02, ...,
#          1.36592834e+00, -1.35643904e+00, -1.50891393e+00],
#        ...,
#        [-8.48473415e-02, -5.66491443e-01, -9.19738471e-01, ...,
#          1.36592834e+00, -1.35643904e+00, -2.59888051e-01],
#        [-7.51443708e-01,  9.80950140e-01,  1.21713976e+00, ...,
#         -1.10499679e+00, -1.33366908e-01, -2.59888051e-01],
#        [ 6.75618973e-01, -5.66491443e-01,  1.84386115e+00, ...,
#          1.30465775e-01,  1.08970523e+00,  9.89137832e-01]])

# %%
x_scaled_test
# Out:
# array([[-4.34538538e-01, -5.92181240e-01, -2.04482670e-01, ...,
#          1.59575579e-01,  1.09769758e+00,  1.04602257e+00],
#        [ 1.20127692e+00, -5.92181240e-01, -5.17395493e-01, ...,
#         -1.05926155e+00,  1.09769758e+00, -2.30652171e-01],
#        [-1.20103497e+00,  9.69623491e-01,  1.73864214e-01, ...,
#          1.37841271e+00, -1.40947663e+00, -2.30652171e-01],
#        ...,
#        [ 3.28373060e-02,  4.09323295e+00, -4.01431142e-01, ...,
#          1.37841271e+00, -1.55889527e-01, -2.30652171e-01],
#        [-1.42420692e+00,  9.69623491e-01,  4.16096962e-01, ...,
#          1.37841271e+00, -1.40947663e+00, -2.30652171e-01],
#        [-4.29330007e-04,  9.69623491e-01, -8.78294325e-01, ...,
#          1.59575579e-01,  1.09769758e+00,  2.32269732e+00]])

# %%
y_train
# Out:
# 5274    5424.938477
# 2697     193.082001
# 1976     254.335602
# 5139     988.047180
# 8073    1031.989990
#            ...
# 599     5502.836914
# 5695    1436.796387
# 8006    2167.844727
# 1361    2700.484863
# 1547     829.586792
# Name: Item_Outlet_Sales, Length: 6392, dtype: float32

# %%
y_test
# Out:
# 8179     904.822205
# 8355    2795.694092
# 3411    1947.464966
# 7089     872.863770
# 6954    2450.144043
#            ...
# 4292    3782.409912
# 4130     327.573608
# 5633    1225.737793
# 2541    2090.612061
# 6985    2777.717529
# Name: Item_Outlet_Sales, Length: 2131, dtype: float32

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
lr.fit(x_scaled_train,y_train)
# Out:
# LinearRegression()

# %%
y_lin_reg_pred=lr.predict(x_scaled_test)

# %%
y_test
# Out:
# 8179     904.822205
# 8355    2795.694092
# 3411    1947.464966
# 7089     872.863770
# 6954    2450.144043
#            ...
# 4292    3782.409912
# 4130     327.573608
# 5633    1225.737793
# 2541    2090.612061
# 6985    2777.717529
# Name: Item_Outlet_Sales, Length: 2131, dtype: float32

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(r2_score(y_test,y_lin_reg_pred))
# Out:
# 0.5065837910905859

# %%
print(mean_absolute_error(y_test,y_lin_reg_pred))
print(np.sqrt(mean_squared_error(y_test,y_lin_reg_pred)))
# Out:
# 881.121624449764
# 1157.6739126280775

# %%
from sklearn.ensemble import RandomForestRegressor
ranfor= RandomForestRegressor(n_estimators=1000)

# %%
ranfor.fit(x_scaled_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
y_lin_reg_pred1= ranfor.predict(x_scaled_test)

# %%
print(r2_score(y_test,y_lin_reg_pred1))
# Out:
# 0.5591425052409456

# %%
print(mean_absolute_error(y_test,y_lin_reg_pred1))
print(np.sqrt(mean_squared_error(y_test,y_lin_reg_pred1)))
# Out:
# 771.2260996314612
# 1094.2804869211548

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# define models and parameters
model = RandomForestRegressor()
n_estimators = [10, 100, 1000]
max_depth=range(1,31)
min_samples_leaf=np.linspace(0.1, 1.0)
max_features=["auto", "sqrt", "log2"]
min_samples_split=np.linspace(0.1, 1.0, 10)

# define grid search
grid = dict(n_estimators=n_estimators)

#cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=101)

grid_search_forest = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, 
                           scoring='r2',error_score=0,verbose=2,cv=2)

grid_search_forest.fit(x_scaled_train,y_train)

# summarize results
print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means = grid_search_forest.cv_results_['mean_test_score']
stds = grid_search_forest.cv_results_['std_test_score']
params = grid_search_forest.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print(f"{mean:.3f} ({stdev:.3f}) with: {param}")
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Best: 0.543 using {'n_estimators': 1000}
# 0.507 (0.001) with: {'n_estimators': 10}
# 0.542 (0.002) with: {'n_estimators': 100}
# 0.543 (0.002) with: {'n_estimators': 1000}

# %%
grid_search_forest.best_params_
# Out:
# {'n_estimators': 1000}

# %%
grid_search_forest.best_score_
# Out:
# 0.5429000575166607

# %%
Y_pred_rf_grid=grid_search_forest.predict(x_scaled_test)

# %%
r2_score(y_test,Y_pred_rf_grid)
# Out:
# 0.5604866365749293
# [CV] END ....................................n_estimators=10; total time=   0.1s
# [CV] END ....................................n_estimators=10; total time=   0.1s
# [CV] END ...................................n_estimators=100; total time=   0.8s
# [CV] END ...................................n_estimators=100; total time=   0.8s
# [CV] END ..................................n_estimators=1000; total time=   8.0s
# [CV] END ..................................n_estimators=1000; total time=   8.3s
